# %%
import numpy as np
from sklearn.metrics import r2_score
from sklearn.datasets import load_diabetes
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import random

# %%
X,y = load_diabetes(return_X_y=True)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(lr.intercept_)
print(lr.coef_)
# Out:
# 151.88331005254165
# [  -9.15865318 -205.45432163  516.69374454  340.61999905 -895.5520019
#   561.22067904  153.89310954  126.73139688  861.12700152   52.42112238]

# %%
lr_pred = lr.predict(X_test)
r2_score(y_test,lr_pred)
# Out:
# 0.439933866156897

# %%
random.sample(range(X_train.shape[0]),7)
# Out:
# [309, 2, 82, 62, 79, 154, 0]

# %%
class Mini_BGD:
    
    def __init__(self,batch_size,learning_rate=0.1,epochs=100):
        self.intercept_=None
        self.coef_=None
        self.lr = learning_rate
        self.epochs = epochs
        self.bs = batch_size
        
    def fit(self,X_train,y_train):
        self.intercept_=0
        self.coef_ = np.ones(X_train.shape[1])
        
        for i in range(self.epochs):
            for j in range(int(X_train.shape[1]/self.bs)):
                idx = random.sample(range(X_train.shape[0]),self.bs)
                
                y_hat = np.dot(X_train[idx],self.coef_) + self.intercept_
                intercept_der = -2*np.mean(y_train[idx]-y_hat)
                self.intercept_ = self.intercept_ - (self.lr*intercept_der)
                
                coef_der = -2*np.dot((y_train[idx]-y_hat),X_train[idx])
                self.coef_ = self.coef_ - (self.lr*coef_der)
        print(self.intercept_,self.coef_)
        
    def predict(self,X_test):
        return np.dot(X_test,self.coef_) + self.intercept_

# %%
mbgd = Mini_BGD(batch_size=int(X_train.shape[0]/50),learning_rate=0.1,epochs=400)
mbgd.fit(X_train,y_train)
mb_pred = mbgd.predict(X_test)
# Out:
# 152.3240021248081 [  23.4213127  -131.35954312  429.57111125  309.62472017   -2.69444047
#   -73.45037804 -164.33645533  105.49501807  381.26334273  116.88006078]

# %%
r2_score(y_test,mb_pred)
# Out:
# 0.4500340158159237

# %%
np.random.randn(200, 1)
# Out:
# array([[-4.09464791e-01],
#        [-4.55593559e-01],
#        [-3.62909496e-01],
#        [-1.02618407e+00],
#        [ 3.08406054e-01],
#        [-3.48546957e-01],
#        [ 1.51295001e-01],
#        [ 2.51648682e+00],
#        [-1.07753610e-01],
#        [-1.18610794e+00],
#        [-7.80567946e-01],
#        [ 4.74725952e-01],
#        [ 1.39133968e+00],
#        [ 1.67259402e+00],
#        [-2.20494783e-01],
#        [ 9.02302989e-01],
#        [ 1.23401415e+00],
#        [ 8.72273720e-01],
#        [-1.29257613e+00],
#        [-1.06760273e-01],
#        [-8.47149638e-01],
#        [-5.18799668e-03],
#        [ 2.69707819e-01],
#        [-5.78917806e-01],
#        [-3.51892771e-01],
#        [-1.72582245e-02],
#        [ 9.07066851e-02],
#        [-9.36352721e-01],
#        [-3.24293628e-02],
#        [ 6.44066344e-01],
#        [ 9.19255543e-02],
#        [-7.32510685e-01],
#        [ 7.54397953e-01],
#        [-1.22483395e+00],
#        [-7.71236175e-01],
# ...
